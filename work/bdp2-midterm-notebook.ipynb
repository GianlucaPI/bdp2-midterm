# %%
from matplotlib import pyplot as plt
import json
import requests

# %%
dataset = requests.get('https://raw.githubusercontent.com/pcm-dpc/COVID-19/master/dati-json/dpc-covid19-ita-andamento-nazionale.json')
covid = json.loads(dataset.content)


dates = []
swabs = []
for day in covid:
    dates.append(day['data'])
    swabs.append(day['tamponi'])

plt.plot(dates, swabs)
